# %%
# !pip install numpy==1.17.4

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !mkdir '/content/gdrive/MyDrive/Projects/blood_cell/updated/results'

# %%
# !mkdir '/content/gdrive/MyDrive/Projects/blood_cell/updated/results/rcnn'

# %% [markdown]
# #Loading all needed libraries

# %% [markdown]
# ### Step 1: Import packages

# %%
import os
import re

# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# #Building the framework using a pre-made structure & Choosing the model

# %%
# If you forked the repository, you can replace the link.
repo_url = 'https://github.com/Tony607/object_detection_demo'

# Number of training steps.
num_steps = 3  # 200000

# Number of evaluation steps.
num_eval_steps = 2

MODELS_CONFIG = {
    'ssd_mobilenet_v2': {
        'model_name': 'ssd_mobilenet_v2_coco_2018_03_29',
        'pipeline_file': 'ssd_mobilenet_v2_coco.config',
        'batch_size': 12
    },
    'faster_rcnn_inception_v2': {
        'model_name': 'faster_rcnn_inception_v2_coco_2018_01_28',
        'pipeline_file': 'faster_rcnn_inception_v2_pets.config',
        'batch_size': 12
    },
    'rfcn_resnet101': {
        'model_name': 'rfcn_resnet101_coco_2018_01_28',
        'pipeline_file': 'rfcn_resnet101_pets.config',
        'batch_size': 8
    }
}

# Pick the model you want to use

selected_model = 'faster_rcnn_inception_v2'

# Name of the object detection model to use.
MODEL = MODELS_CONFIG[selected_model]['model_name']

# Name of the pipline file in tensorflow object detection API.
pipeline_file = MODELS_CONFIG[selected_model]['pipeline_file']

# Training batch size fits in Colabe's Tesla K80 GPU memory for selected model.
batch_size = MODELS_CONFIG[selected_model]['batch_size']

# %%
# %cd /content

repo_dir_path = os.path.abspath(os.path.join('.', os.path.basename(repo_url)))

# !git clone {repo_url}
# %cd {repo_dir_path}
# !git pull
# Out:
# /content
# Cloning into 'object_detection_demo'...
# remote: Enumerating objects: 124, done.
# remote: Total 124 (delta 0), reused 0 (delta 0), pack-reused 124
# Receiving objects: 100% (124/124), 11.16 MiB | 16.92 MiB/s, done.
# Resolving deltas: 100% (55/55), done.
# /content/object_detection_demo
# Already up to date.

# %% [markdown]
# ### Step 3: Download Google Object Detection API and other dependencies

# %%
# %cd /content

#!git clone --quiet https://github.com/tensorflow/models.git

# !git clone --branch r1.13.0 --depth 1 https://github.com/tensorflow/models.git


# !apt-get install -qq protobuf-compiler python-pil python-lxml python-tk

# !pip install -q Cython contextlib2 pillow lxml matplotlib

# !pip install -q pycocotools

# %cd /content/models/research
# !protoc object_detection/protos/*.proto --python_out=.

import os
os.environ['PYTHONPATH'] += ':/content/models/research/:/content/models/research/slim/'

# !python object_detection/builders/model_builder_test.py
# Out:
# /content
# Cloning into 'models'...
# remote: Enumerating objects: 2927, done.
# remote: Counting objects: 100% (2927/2927), done.
# remote: Compressing objects: 100% (2428/2428), done.
# remote: Total 2927 (delta 505), reused 2108 (delta 424), pack-reused 0
# Receiving objects: 100% (2927/2927), 369.04 MiB | 37.88 MiB/s, done.
# Resolving deltas: 100% (505/505), done.
# Checking out files: 100% (2768/2768), done.
# Selecting previously unselected package python-bs4.
# (Reading database ... 160706 files and directories currently installed.)
# Preparing to unpack .../0-python-bs4_4.6.0-1_all.deb ...
# Unpacking python-bs4 (4.6.0-1) ...
# Selecting previously unselected package python-pkg-resources.
# Preparing to unpack .../1-python-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python-chardet.
# Preparing to unpack .../2-python-chardet_3.0.4-1_all.deb ...
# Unpacking python-chardet (3.0.4-1) ...
# Selecting previously unselected package python-six.
# Preparing to unpack .../3-python-six_1.11.0-2_all.deb ...
# Unpacking python-six (1.11.0-2) ...
# Selecting previously unselected package python-webencodings.
# Preparing to unpack .../4-python-webencodings_0.5-2_all.deb ...
# Unpacking python-webencodings (0.5-2) ...
# Selecting previously unselected package python-html5lib.
# Preparing to unpack .../5-python-html5lib_0.999999999-1_all.deb ...
# Unpacking python-html5lib (0.999999999-1) ...
# Selecting previously unselected package python-lxml:amd64.
# Preparing to unpack .../6-python-lxml_4.2.1-1ubuntu0.4_amd64.deb ...
# Unpacking python-lxml:amd64 (4.2.1-1ubuntu0.4) ...
# Selecting previously unselected package python-olefile.
# Preparing to unpack .../7-python-olefile_0.45.1-1_all.deb ...
# Unpacking python-olefile (0.45.1-1) ...
# Selecting previously unselected package python-pil:amd64.
# Preparing to unpack .../8-python-pil_5.1.0-1ubuntu0.5_amd64.deb ...
# Unpacking python-pil:amd64 (5.1.0-1ubuntu0.5) ...
# Setting up python-pkg-resources (39.0.1-2) ...
# Setting up python-six (1.11.0-2) ...
# Setting up python-bs4 (4.6.0-1) ...
# Setting up python-lxml:amd64 (4.2.1-1ubuntu0.4) ...
# Setting up python-olefile (0.45.1-1) ...
# Setting up python-pil:amd64 (5.1.0-1ubuntu0.5) ...
# Setting up python-webencodings (0.5-2) ...
# Setting up python-chardet (3.0.4-1) ...
# Setting up python-html5lib (0.999999999-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# /content/models/research
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/models/research/slim/nets/inception_resnet_v2.py:373: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/models/research/slim/nets/mobilenet/mobilenet.py:389: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# Running tests under Python 3.7.10: /usr/bin/python3
# [ RUN      ] ModelBuilderTest.test_create_embedded_ssd_mobilenet_v1_model_from_config
# [       OK ] ModelBuilderTest.test_create_embedded_ssd_mobilenet_v1_model_from_config
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_inception_resnet_v2_model_from_config
# WARNING:tensorflow:From /content/models/research/object_detection/anchor_generators/grid_anchor_generator.py:59: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0520 10:41:40.058578 140435860797312 deprecation.py:323] From /content/models/research/object_detection/anchor_generators/grid_anchor_generator.py:59: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_inception_resnet_v2_model_from_config
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_inception_v2_model_from_config
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_inception_v2_model_from_config
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_model_from_config_with_example_miner
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_nas_model_from_config
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_nas_model_from_config
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_pnas_model_from_config
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_pnas_model_from_config
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_resnet101_with_mask_prediction_enabled0 (use_matmul_crop_and_resize=False)
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_resnet101_with_mask_prediction_enabled0 (use_matmul_crop_and_resize=False)
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_resnet101_with_mask_prediction_enabled1 (use_matmul_crop_and_resize=True)
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_resnet101_with_mask_prediction_enabled1 (use_matmul_crop_and_resize=True)
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_resnet_v1_models_from_config
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_resnet_v1_models_from_config
# [ RUN      ] ModelBuilderTest.test_create_rfcn_resnet_v1_model_from_config
# [       OK ] ModelBuilderTest.test_create_rfcn_resnet_v1_model_from_config
# [ RUN      ] ModelBuilderTest.test_create_ssd_inception_v2_model_from_config
# [       OK ] ModelBuilderTest.test_create_ssd_inception_v2_model_from_config
# [ RUN      ] ModelBuilderTest.test_create_ssd_inception_v3_model_from_config
# [       OK ] ModelBuilderTest.test_create_ssd_inception_v3_model_from_config
# [ RUN      ] ModelBuilderTest.test_create_ssd_mobilenet_v1_fpn_model_from_config
# [       OK ] ModelBuilderTest.test_create_ssd_mobilenet_v1_fpn_model_from_config
# [ RUN      ] ModelBuilderTest.test_create_ssd_mobilenet_v1_model_from_config
# [       OK ] ModelBuilderTest.test_create_ssd_mobilenet_v1_model_from_config
# [ RUN      ] ModelBuilderTest.test_create_ssd_mobilenet_v1_ppn_model_from_config
# [       OK ] ModelBuilderTest.test_create_ssd_mobilenet_v1_ppn_model_from_config
# [ RUN      ] ModelBuilderTest.test_create_ssd_mobilenet_v2_fpn_model_from_config
# [       OK ] ModelBuilderTest.test_create_ssd_mobilenet_v2_fpn_model_from_config
# [ RUN      ] ModelBuilderTest.test_create_ssd_mobilenet_v2_fpnlite_model_from_config
# [       OK ] ModelBuilderTest.test_create_ssd_mobilenet_v2_fpnlite_model_from_config
# [ RUN      ] ModelBuilderTest.test_create_ssd_mobilenet_v2_keras_model_from_config
# [       OK ] ModelBuilderTest.test_create_ssd_mobilenet_v2_keras_model_from_config
# [ RUN      ] ModelBuilderTest.test_create_ssd_mobilenet_v2_model_from_config
# [       OK ] ModelBuilderTest.test_create_ssd_mobilenet_v2_model_from_config
# [ RUN      ] ModelBuilderTest.test_create_ssd_resnet_v1_fpn_model_from_config
# [       OK ] ModelBuilderTest.test_create_ssd_resnet_v1_fpn_model_from_config
# [ RUN      ] ModelBuilderTest.test_create_ssd_resnet_v1_ppn_model_from_config
# [       OK ] ModelBuilderTest.test_create_ssd_resnet_v1_ppn_model_from_config
# [ RUN      ] ModelBuilderTest.test_session
# [  SKIPPED ] ModelBuilderTest.test_session
# ----------------------------------------------------------------------
# Ran 22 tests in 0.092s
#
# OK (skipped=1)

# %% [markdown]
# #Emptying the Train & Test Folders

# %%
import shutil
shutil.rmtree('/content/object_detection_demo/data/images/train')
shutil.rmtree('/content/object_detection_demo/data/images/test')

# %% [markdown]
# #Loading the Dataset

# %%
# !unzip '/content/gdrive/MyDrive/Projects/blood_cell/updated/BloodRBC-Detection-Dataset-Processed-(1).zip' -d '/content/object_detection_demo/data'
# Out:
# Archive:  /content/gdrive/MyDrive/Projects/blood_cell/updated/BloodRBC-Detection-Dataset-Processed-(1).zip
#    creating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00410.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00410.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00409.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00409.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00408.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00408.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00407.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00407.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00405.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00405.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00404.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00404.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00403.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00403.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00402.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00402.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00400.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00400.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00398.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00398.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00397.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00397.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00396.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00396.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00395.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00395.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00393.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00393.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00392.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00392.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00391.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00391.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00390.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00390.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00389.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00389.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00388.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00388.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00387.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00387.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00386.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00386.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00385.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00385.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00384.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00384.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00383.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00383.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00382.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00382.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00381.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00381.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00379.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00379.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00378.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00378.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00377.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00377.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00376.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00376.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00375.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00375.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00374.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00374.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00372.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00372.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00371.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00371.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00370.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00370.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00369.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00369.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00368.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00368.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00367.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00367.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00366.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00366.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00365.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00365.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00364.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00364.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00362.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00362.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00361.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00361.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00360.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00360.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00359.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00359.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00357.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00357.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00356.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00356.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00355.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00355.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00354.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00354.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00353.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00353.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00352.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00352.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00351.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00351.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00349.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00349.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00348.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00348.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00347.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00347.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00346.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00346.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00345.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00345.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00344.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00344.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00343.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00343.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00342.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00342.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00341.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00341.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00340.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00340.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00339.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00339.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00338.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00338.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00337.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00337.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00336.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00336.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00335.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00335.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00334.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00334.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00333.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00333.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00332.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00332.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00331.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00331.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00326.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00326.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00325.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00325.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00324.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00324.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00320.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00320.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00319.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00319.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00318.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00318.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00317.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00317.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00315.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00315.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00314.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00314.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00313.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00313.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00312.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00312.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00311.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00311.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00310.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00310.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00309.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00309.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00308.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00308.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00307.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00307.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00305.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00305.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00304.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00304.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00302.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00302.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00301.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00301.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00300.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00300.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00299.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00299.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00298.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00298.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00297.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00297.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00296.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00296.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00295.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00295.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00294.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00294.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00293.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00293.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00292.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00292.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00291.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00291.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00290.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00290.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00289.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00289.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00288.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00288.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00287.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00287.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00285.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00285.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00284.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00284.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00283.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00283.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00282.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00282.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00281.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00281.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00279.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00279.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00278.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00278.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00277.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00277.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00276.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00276.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00275.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00275.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00274.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00274.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00273.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00273.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00272.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00272.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00271.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00271.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00269.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00269.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00266.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00266.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00265.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00265.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00264.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00264.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00263.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00263.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00262.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00262.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00261.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00261.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00260.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00260.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00259.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00259.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00258.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00257.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00257.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00256.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00256.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00255.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00255.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00254.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00254.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00253.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00253.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00252.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00252.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00251.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00251.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00250.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00249.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00248.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00248.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00247.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00247.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00246.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00246.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00245.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00245.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00244.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00244.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00243.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00243.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00242.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00242.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00241.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00241.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00240.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00240.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00239.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00239.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00237.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00237.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00236.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00236.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00235.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00235.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00234.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00234.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00233.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00233.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00232.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00232.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00231.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00231.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00230.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00230.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00229.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00229.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00228.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00228.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00227.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00227.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00226.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00226.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00225.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00225.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00224.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00223.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00223.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00222.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00222.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00221.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00221.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00220.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00220.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00219.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00219.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00218.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00218.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00217.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00217.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00216.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00216.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00215.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00215.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00214.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00214.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00212.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00212.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00211.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00211.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00210.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00210.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00209.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00209.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00208.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00208.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00207.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00207.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00206.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00206.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00205.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00205.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00204.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00204.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00203.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00203.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00202.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00202.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00201.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00201.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00200.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00200.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00199.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00199.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00198.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00198.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00197.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00197.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00196.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00196.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00195.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00195.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00193.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00193.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00192.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00192.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00191.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00191.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00190.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00190.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00189.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00189.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00184.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00184.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00183.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00183.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00182.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00182.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00180.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00180.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00179.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00179.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00178.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00178.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00177.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00177.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00176.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00176.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00175.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00175.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00174.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00174.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00172.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00172.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00171.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00171.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00170.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00170.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00169.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00169.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00168.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00168.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00167.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00167.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00166.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00166.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00165.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00165.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00164.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00164.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00163.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00163.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00162.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00162.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00161.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00161.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00160.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00160.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00159.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00159.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00158.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00158.jpeg
# ...
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00078.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00077.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00077.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00076.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00076.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00075.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00075.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00074.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00074.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00073.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00073.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00072.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00072.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00071.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00071.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00070.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00070.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00069.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00069.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00068.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00068.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00067.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00067.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00066.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00066.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00065.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00065.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00064.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00064.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00063.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00063.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00062.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00062.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00059.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00059.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00058.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00058.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00057.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00057.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00056.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00056.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00055.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00055.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00054.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00054.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00053.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00053.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00052.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00052.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00050.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00050.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00049.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00049.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00048.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00048.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00047.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00047.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00046.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00046.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00045.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00045.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00044.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00044.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00043.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00043.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00042.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00041.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00041.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00040.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00040.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00039.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00039.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00038.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00038.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00037.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00037.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00036.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00036.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00035.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00035.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00034.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00034.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00033.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00033.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00032.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00032.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00031.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00031.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00030.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00030.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00029.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00029.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00028.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00028.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00026.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00026.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00024.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00024.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00023.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00023.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00022.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00022.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00021.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00021.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00020.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00020.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00019.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00019.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00018.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00018.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00017.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00017.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00016.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00016.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00015.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00015.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00014.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00014.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00013.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00013.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00012.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00012.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00011.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00011.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00010.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00010.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00009.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00009.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00008.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00008.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00007.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00007.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00006.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00006.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00005.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00005.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00004.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00004.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00003.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00003.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00002.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00002.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00001.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00001.jpeg
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00000.xml
#   inflating: /content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/BloodImage_00000.jpeg

# %% [markdown]
# #Splitting into train & test including annotations

# %%
# !pip install annotated_images
import annotated_images

# To only split into training and validation set, set a tuple to `ratio`, i.e, `(.8, .2)`.
annotated_images.split('/content/object_detection_demo/data/BloodRBC-Detection-Dataset-Processed/', "/content/object_detection_demo/data/images", seed=1337, ratio=(.95, .05))
# Out:
# Collecting annotated_images
#   Downloading https://files.pythonhosted.org/packages/50/d6/e04b595a2d16847e66afdcc047bfff42607c34b6010327758aec89c5cc0a/annotated_images-0.1.4.tar.gz
# Building wheels for collected packages: annotated-images
#   Building wheel for annotated-images (setup.py) ... done
#   Created wheel for annotated-images: filename=annotated_images-0.1.4-cp37-none-any.whl size=4290 sha256=5980a082e4f1f69378f6a09443f8ed4b136fa04e212e83d01aba12583d3ea4f9
#   Stored in directory: /root/.cache/pip/wheels/e7/8c/ae/8e1889114b9dcac3145ec097133e6880eb5de1bd2eeb69a304
# Successfully built annotated-images
# Installing collected packages: annotated-images
# Successfully installed annotated-images-0.1.4
# {'test': 18, 'total': 343, 'train': 325}

# %% [markdown]
# ##Task-2: Conversion of XML annotations and images into tfrecords for training and testing datasets

# %% [markdown]
# ### Step 4: Prepare `tfrecord` files
#
# Use the following scripts to generate the `tfrecord` files.
# ```bash
# # Convert train folder annotation xml files to a single csv file,
# # generate the `label_map.pbtxt` file to `data/` directory as well.
# python xml_to_csv.py -i data/images/train -o data/annotations/train_labels.csv -l data/annotations
#
# # Convert test folder annotation xml files to a single csv.
# python xml_to_csv.py -i data/images/test -o data/annotations/test_labels.csv
#
# # Generate `train.record`
# python generate_tfrecord.py --csv_input=data/annotations/train_labels.csv --output_path=data/annotations/train.record --img_path=data/images/train --label_map data/annotations/label_map.pbtxt
#
# # Generate `test.record`
# python generate_tfrecord.py --csv_input=data/annotations/test_labels.csv --output_path=data/annotations/test.record --img_path=data/images/test --label_map data/annotations/label_map.pbtxt
# ```

# %%
# %cd {repo_dir_path}

# Convert train folder annotation xml files to a single csv file,
# generate the `label_map.pbtxt` file to `data/` directory as well.
# !python xml_to_csv.py -i data/images/train -o data/annotations/train_labels.csv -l data/annotations

# Convert test folder annotation xml files to a single csv.
# !python xml_to_csv.py -i data/images/test -o data/annotations/test_labels.csv

# Generate `train.record`
# !python generate_tfrecord.py --csv_input=data/annotations/train_labels.csv --output_path=data/annotations/train.record --img_path=data/images/train --label_map data/annotations/label_map.pbtxt

# Generate `test.record`
# !python generate_tfrecord.py --csv_input=data/annotations/test_labels.csv --output_path=data/annotations/test.record --img_path=data/images/test --label_map data/annotations/label_map.pbtxt
# Out:
# /content/object_detection_demo
# Successfully converted xml to csv.
# Generate `data/annotations/label_map.pbtxt`
# Successfully converted xml to csv.
# WARNING:tensorflow:From generate_tfrecord.py:134: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From generate_tfrecord.py:107: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# W0520 10:41:50.049067 140667488642944 module_wrapper.py:139] From generate_tfrecord.py:107: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/utils/label_map_util.py:132: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0520 10:41:50.062102 140667488642944 module_wrapper.py:139] From /content/models/research/object_detection/utils/label_map_util.py:132: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# Successfully created the TFRecords: /content/object_detection_demo/data/annotations/train.record
# WARNING:tensorflow:From generate_tfrecord.py:134: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From generate_tfrecord.py:107: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# W0520 10:41:52.649972 139852629436288 module_wrapper.py:139] From generate_tfrecord.py:107: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/utils/label_map_util.py:132: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0520 10:41:52.655781 139852629436288 module_wrapper.py:139] From /content/models/research/object_detection/utils/label_map_util.py:132: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# Successfully created the TFRecords: /content/object_detection_demo/data/annotations/test.record

# %%
test_record_fname = '/content/object_detection_demo/data/annotations/test.record'
train_record_fname = '/content/object_detection_demo/data/annotations/train.record'
label_map_pbtxt_fname = '/content/object_detection_demo/data/annotations/label_map.pbtxt'

# %% [markdown]
# ### Step 5. Download the base model for transfer learning

# %%
# %cd /content/models/research

import os
import shutil
import glob
import urllib.request
import tarfile
MODEL_FILE = MODEL + '.tar.gz'
DOWNLOAD_BASE = 'http://download.tensorflow.org/models/object_detection/'
DEST_DIR = '/content/models/research/pretrained_model'

if not (os.path.exists(MODEL_FILE)):
    urllib.request.urlretrieve(DOWNLOAD_BASE + MODEL_FILE, MODEL_FILE)

tar = tarfile.open(MODEL_FILE)
tar.extractall()
tar.close()

os.remove(MODEL_FILE)
if (os.path.exists(DEST_DIR)):
    shutil.rmtree(DEST_DIR)
os.rename(MODEL, DEST_DIR)
# Out:
# /content/models/research

# %%
# !echo {DEST_DIR}
# !ls -alh {DEST_DIR}
# Out:
# /content/models/research/pretrained_model
# total 111M
# drwxr-xr-x  3 345018 5000 4.0K Feb  1  2018 .
# drwxr-xr-x 70 root   root 4.0K May 20 10:41 ..
# -rw-r--r--  1 345018 5000   77 Feb  1  2018 checkpoint
# -rw-r--r--  1 345018 5000  55M Feb  1  2018 frozen_inference_graph.pb
# -rw-r--r--  1 345018 5000  51M Feb  1  2018 model.ckpt.data-00000-of-00001
# -rw-r--r--  1 345018 5000  16K Feb  1  2018 model.ckpt.index
# -rw-r--r--  1 345018 5000 5.5M Feb  1  2018 model.ckpt.meta
# -rw-r--r--  1 345018 5000 3.2K Feb  1  2018 pipeline.config
# drwxr-xr-x  3 345018 5000 4.0K Feb  1  2018 saved_model

# %%
fine_tune_checkpoint = os.path.join(DEST_DIR, "model.ckpt")
fine_tune_checkpoint
# Out:
# '/content/models/research/pretrained_model/model.ckpt'

# %% [markdown]
# ##Task-3: Training: Transfer learning from already trained models

# %% [markdown]
# ###Step 6: configuring a training pipeline

# %%
import os
pipeline_fname = os.path.join('/content/models/research/object_detection/samples/configs/', pipeline_file)

assert os.path.isfile(pipeline_fname), '`{}` not exist'.format(pipeline_fname)

# %%
def get_num_classes(pbtxt_fname):
    from object_detection.utils import label_map_util
    label_map = label_map_util.load_labelmap(pbtxt_fname)
    categories = label_map_util.convert_label_map_to_categories(
        label_map, max_num_classes=90, use_display_name=True)
    category_index = label_map_util.create_category_index(categories)
    return len(category_index.keys())

# %%
num_classes = get_num_classes(label_map_pbtxt_fname)
with open(pipeline_fname) as f:
    s = f.read()
with open(pipeline_fname, 'w') as f:
    
    # fine_tune_checkpoint
    s = re.sub('fine_tune_checkpoint: ".*?"',
               'fine_tune_checkpoint: "{}"'.format(fine_tune_checkpoint), s)
    
    # tfrecord files train and test.
    s = re.sub(
        '(input_path: ".*?)(train.record)(.*?")', 'input_path: "{}"'.format(train_record_fname), s)
    s = re.sub(
        '(input_path: ".*?)(val.record)(.*?")', 'input_path: "{}"'.format(test_record_fname), s)

    # label_map_path
    s = re.sub(
        'label_map_path: ".*?"', 'label_map_path: "{}"'.format(label_map_pbtxt_fname), s)

    # Set training batch_size.
    s = re.sub('batch_size: [0-9]+',
               'batch_size: {}'.format(batch_size), s)

    # Set training steps, num_steps
    s = re.sub('num_steps: [0-9]+',
               'num_steps: {}'.format(num_steps), s)
    
    # Set number of classes num_classes.
    s = re.sub('num_classes: [0-9]+',
               'num_classes: {}'.format(num_classes), s)
    f.write(s)
# Out:
# WARNING:tensorflow:From /content/models/research/object_detection/utils/label_map_util.py:132: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.

# %%
# !cat {pipeline_fname}
# Out:
# # Faster R-CNN with Inception v2, configured for Oxford-IIIT Pets Dataset.
# # Users should configure the fine_tune_checkpoint field in the train config as
# # well as the label_map_path and input_path fields in the train_input_reader and
# # eval_input_reader. Search for "PATH_TO_BE_CONFIGURED" to find the fields that
# # should be configured.
#
# model {
#   faster_rcnn {
#     num_classes: 1
#     image_resizer {
#       keep_aspect_ratio_resizer {
#         min_dimension: 600
#         max_dimension: 1024
#       }
#     }
#     feature_extractor {
#       type: 'faster_rcnn_inception_v2'
#       first_stage_features_stride: 16
#     }
#     first_stage_anchor_generator {
#       grid_anchor_generator {
#         scales: [0.25, 0.5, 1.0, 2.0]
#         aspect_ratios: [0.5, 1.0, 2.0]
#         height_stride: 16
#         width_stride: 16
#       }
#     }
#     first_stage_box_predictor_conv_hyperparams {
#       op: CONV
#       regularizer {
#         l2_regularizer {
#           weight: 0.0
#         }
#       }
#       initializer {
#         truncated_normal_initializer {
#           stddev: 0.01
#         }
#       }
#     }
#     first_stage_nms_score_threshold: 0.0
#     first_stage_nms_iou_threshold: 0.7
#     first_stage_max_proposals: 300
#     first_stage_localization_loss_weight: 2.0
#     first_stage_objectness_loss_weight: 1.0
#     initial_crop_size: 14
#     maxpool_kernel_size: 2
#     maxpool_stride: 2
#     second_stage_box_predictor {
#       mask_rcnn_box_predictor {
#         use_dropout: false
#         dropout_keep_probability: 1.0
#         fc_hyperparams {
#           op: FC
#           regularizer {
#             l2_regularizer {
#               weight: 0.0
#             }
#           }
#           initializer {
#             variance_scaling_initializer {
#               factor: 1.0
#               uniform: true
#               mode: FAN_AVG
#             }
#           }
#         }
#       }
#     }
#     second_stage_post_processing {
#       batch_non_max_suppression {
#         score_threshold: 0.0
#         iou_threshold: 0.6
#         max_detections_per_class: 100
#         max_total_detections: 300
#       }
#       score_converter: SOFTMAX
#     }
#     second_stage_localization_loss_weight: 2.0
#     second_stage_classification_loss_weight: 1.0
#   }
# }
#
# train_config: {
#   batch_size: 12
#   optimizer {
#     momentum_optimizer: {
#       learning_rate: {
#         manual_step_learning_rate {
#           initial_learning_rate: 0.0002
#           schedule {
#             step: 900000
#             learning_rate: .00002
#           }
#           schedule {
#             step: 1200000
#             learning_rate: .000002
#           }
#         }
#       }
#       momentum_optimizer_value: 0.9
#     }
#     use_moving_average: false
#   }
#   gradient_clipping_by_norm: 10.0
#   fine_tune_checkpoint: "/content/models/research/pretrained_model/model.ckpt"
#   from_detection_checkpoint: true
#   load_all_detection_checkpoint_vars: true
#   # Note: The below line limits the training process to 200K steps, which we
#   # empirically found to be sufficient enough to train the pets dataset. This
#   # effectively bypasses the learning rate schedule (the learning rate will
#   # never decay). Remove the below line to train indefinitely.
#   num_steps: 3
#   data_augmentation_options {
#     random_horizontal_flip {
#     }
#   }
# }
#
#
# train_input_reader: {
#   tf_record_input_reader {
#     input_path: "/content/object_detection_demo/data/annotations/train.record"
#   }
#   label_map_path: "/content/object_detection_demo/data/annotations/label_map.pbtxt"
# }
#
# eval_config: {
#   metrics_set: "coco_detection_metrics"
#   num_examples: 1101
# }
#
# eval_input_reader: {
#   tf_record_input_reader {
#     input_path: "/content/object_detection_demo/data/annotations/test.record"
#   }
#   label_map_path: "/content/object_detection_demo/data/annotations/label_map.pbtxt"
#   shuffle: false
#   num_readers: 1
# }

# %%
model_dir = 'training/'
# Optionally remove content in output model directory to fresh start.
# !rm -rf {model_dir}
os.makedirs(model_dir, exist_ok=True)

# %% [markdown]
# ### Step 7. Install Tensorboard to visualize the progress of training process

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip -o ngrok-stable-linux-amd64.zip
# Out:
# --2021-05-20 10:41:57--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 34.193.233.154, 52.204.244.158, 54.209.238.187, ...
# Connecting to bin.equinox.io (bin.equinox.io)|34.193.233.154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13832437 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.19M  19.5MB/s    in 0.7s
#
# 2021-05-20 10:41:58 (19.5 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13832437/13832437]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
LOG_DIR = model_dir
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)

# %%
get_ipython().system_raw('./ngrok http 6006 &')

# %% [markdown]
# ### Step: 8 Get tensorboard link

# %%
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
# IndexError: list index out of range

# %% [markdown]
# ### Step 9.  Training the model

# %%
# !python /content/models/research/object_detection/model_main.py \
    --pipeline_config_path={pipeline_fname} \
    --model_dir={model_dir} \
    --alsologtostderr \
    --num_train_steps={num_steps} \
    --num_eval_steps={num_eval_steps}
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/models/research/slim/nets/inception_resnet_v2.py:373: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/models/research/slim/nets/mobilenet/mobilenet.py:389: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/model_main.py:109: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/utils/config_util.py:94: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0520 10:42:02.975000 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/utils/config_util.py:94: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/model_lib.py:573: The name tf.logging.warning is deprecated. Please use tf.compat.v1.logging.warning instead.
#
# W0520 10:42:02.977649 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/model_lib.py:573: The name tf.logging.warning is deprecated. Please use tf.compat.v1.logging.warning instead.
#
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0520 10:42:02.977792 139664952031104 model_lib.py:574] Forced number of epochs for all eval validations to be 1.
# WARNING:tensorflow:From /content/models/research/object_detection/utils/config_util.py:480: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# W0520 10:42:02.977933 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/utils/config_util.py:480: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# INFO:tensorflow:Maybe overwriting train_steps: 3
# I0520 10:42:02.978026 139664952031104 config_util.py:480] Maybe overwriting train_steps: 3
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: 1
# I0520 10:42:02.978119 139664952031104 config_util.py:480] Maybe overwriting sample_1_of_n_eval_examples: 1
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0520 10:42:02.978205 139664952031104 config_util.py:480] Maybe overwriting eval_num_epochs: 1
# INFO:tensorflow:Maybe overwriting load_pretrained: True
# I0520 10:42:02.978279 139664952031104 config_util.py:480] Maybe overwriting load_pretrained: True
# INFO:tensorflow:Ignoring config override key: load_pretrained
# I0520 10:42:02.978351 139664952031104 config_util.py:490] Ignoring config override key: load_pretrained
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# W0520 10:42:02.978457 139664952031104 model_lib.py:590] Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# INFO:tensorflow:create_estimator_and_inputs: use_tpu False, export_to_tpu False
# I0520 10:42:02.978573 139664952031104 model_lib.py:623] create_estimator_and_inputs: use_tpu False, export_to_tpu False
# INFO:tensorflow:Using config: {'_model_dir': 'training/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f05dc903a90>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# I0520 10:42:02.979016 139664952031104 estimator.py:212] Using config: {'_model_dir': 'training/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f05dc903a90>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:Estimator's model_fn (<function create_model_fn.<locals>.model_fn at 0x7f05dc652560>) includes params argument, but params are not passed to Estimator.
# W0520 10:42:02.979230 139664952031104 model_fn.py:630] Estimator's model_fn (<function create_model_fn.<locals>.model_fn at 0x7f05dc652560>) includes params argument, but params are not passed to Estimator.
# INFO:tensorflow:Not using Distribute Coordinator.
# I0520 10:42:02.979628 139664952031104 estimator_training.py:186] Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# I0520 10:42:02.979796 139664952031104 training.py:612] Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# I0520 10:42:02.979999 139664952031104 training.py:700] Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# W0520 10:42:02.984592 139664952031104 deprecation.py:323] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /content/models/research/object_detection/data_decoders/tf_example_decoder.py:167: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.
#
# W0520 10:42:02.992430 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/data_decoders/tf_example_decoder.py:167: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/data_decoders/tf_example_decoder.py:182: The name tf.VarLenFeature is deprecated. Please use tf.io.VarLenFeature instead.
#
# W0520 10:42:02.992640 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/data_decoders/tf_example_decoder.py:182: The name tf.VarLenFeature is deprecated. Please use tf.io.VarLenFeature instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/builders/dataset_builder.py:61: The name tf.gfile.Glob is deprecated. Please use tf.io.gfile.glob instead.
#
# W0520 10:42:03.002982 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/builders/dataset_builder.py:61: The name tf.gfile.Glob is deprecated. Please use tf.io.gfile.glob instead.
#
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0520 10:42:03.003894 139664952031104 dataset_builder.py:66] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /content/models/research/object_detection/builders/dataset_builder.py:80: parallel_interleave (from tensorflow.contrib.data.python.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.experimental.parallel_interleave(...)`.
# W0520 10:42:03.008286 139664952031104 deprecation.py:323] From /content/models/research/object_detection/builders/dataset_builder.py:80: parallel_interleave (from tensorflow.contrib.data.python.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.experimental.parallel_interleave(...)`.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/contrib/data/python/ops/interleave_ops.py:77: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.experimental.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_determinstic`.
# W0520 10:42:03.008438 139664952031104 deprecation.py:323] From /tensorflow-1.15.2/python3.7/tensorflow_core/contrib/data/python/ops/interleave_ops.py:77: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.experimental.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_determinstic`.
# WARNING:tensorflow:Entity <function build.<locals>.process_fn at 0x7f05dc6527a0> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# W0520 10:42:03.040867 139664952031104 ag_logging.py:146] Entity <function build.<locals>.process_fn at 0x7f05dc6527a0> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# 2021-05-20 10:42:03.074272: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-05-20 10:42:03.126442: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:42:03.127131: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2021-05-20 10:42:03.138048: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-20 10:42:03.358518: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-05-20 10:42:03.471085: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-05-20 10:42:03.517344: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-05-20 10:42:03.808605: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-05-20 10:42:03.831916: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-05-20 10:42:04.344770: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-05-20 10:42:04.344993: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:42:04.345774: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:42:04.346319: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# WARNING:tensorflow:From /content/models/research/object_detection/anchor_generators/grid_anchor_generator.py:59: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0520 10:42:04.445986 139664952031104 deprecation.py:323] From /content/models/research/object_detection/anchor_generators/grid_anchor_generator.py:59: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /content/models/research/object_detection/utils/ops.py:466: The name tf.is_nan is deprecated. Please use tf.math.is_nan instead.
#
# W0520 10:42:04.448531 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/utils/ops.py:466: The name tf.is_nan is deprecated. Please use tf.math.is_nan instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/utils/ops.py:466: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0520 10:42:04.449110 139664952031104 deprecation.py:323] From /content/models/research/object_detection/utils/ops.py:466: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /content/models/research/object_detection/utils/ops.py:468: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0520 10:42:04.451607 139664952031104 deprecation.py:323] From /content/models/research/object_detection/utils/ops.py:468: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/models/research/object_detection/core/preprocessor.py:512: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0520 10:42:04.469421 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/core/preprocessor.py:512: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/core/preprocessor.py:2236: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# W0520 10:42:04.516137 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/core/preprocessor.py:2236: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/inputs.py:374: The name tf.string_to_hash_bucket_fast is deprecated. Please use tf.strings.to_hash_bucket_fast instead.
#
# W0520 10:42:04.752675 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/inputs.py:374: The name tf.string_to_hash_bucket_fast is deprecated. Please use tf.strings.to_hash_bucket_fast instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/builders/dataset_builder.py:148: batch_and_drop_remainder (from tensorflow.contrib.data.python.ops.batching) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.batch(..., drop_remainder=True)`.
# W0520 10:42:04.776273 139664952031104 deprecation.py:323] From /content/models/research/object_detection/builders/dataset_builder.py:148: batch_and_drop_remainder (from tensorflow.contrib.data.python.ops.batching) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.batch(..., drop_remainder=True)`.
# INFO:tensorflow:Calling model_fn.
# I0520 10:42:04.786841 139664952031104 estimator.py:1148] Calling model_fn.
# WARNING:tensorflow:From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:162: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0520 10:42:04.935078 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:162: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/contrib/layers/python/layers/layers.py:2784: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W0520 10:42:04.944428 139664952031104 deprecation.py:323] From /tensorflow-1.15.2/python3.7/tensorflow_core/contrib/layers/python/layers/layers.py:2784: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /content/models/research/object_detection/core/anchor_generator.py:149: The name tf.assert_equal is deprecated. Please use tf.compat.v1.assert_equal instead.
#
# W0520 10:42:06.299743 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/core/anchor_generator.py:149: The name tf.assert_equal is deprecated. Please use tf.compat.v1.assert_equal instead.
#
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0520 10:42:06.305860 139664952031104 regularizers.py:98] Scale of 0 disables regularizer.
# WARNING:tensorflow:From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:986: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# W0520 10:42:06.306228 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:986: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0520 10:42:06.319208 139664952031104 regularizers.py:98] Scale of 0 disables regularizer.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0520 10:42:06.319602 139664952031104 convolutional_box_predictor.py:148] depth of additional conv before box predictor: 0
# WARNING:tensorflow:From /content/models/research/object_detection/box_coders/faster_rcnn_box_coder.py:82: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0520 10:42:07.136181 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/box_coders/faster_rcnn_box_coder.py:82: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/core/minibatch_sampler.py:81: The name tf.random_shuffle is deprecated. Please use tf.random.shuffle instead.
#
# W0520 10:42:07.175909 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/core/minibatch_sampler.py:81: The name tf.random_shuffle is deprecated. Please use tf.random.shuffle instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/utils/ops.py:1085: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# W0520 10:42:09.776802 139664952031104 deprecation.py:506] From /content/models/research/object_detection/utils/ops.py:1085: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# WARNING:tensorflow:From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:185: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# W0520 10:42:09.799638 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:185: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/contrib/layers/python/layers/layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# W0520 10:42:10.254163 139664952031104 deprecation.py:323] From /tensorflow-1.15.2/python3.7/tensorflow_core/contrib/layers/python/layers/layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0520 10:42:10.256312 139664952031104 regularizers.py:98] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0520 10:42:10.272122 139664952031104 regularizers.py:98] Scale of 0 disables regularizer.
# WARNING:tensorflow:From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:2235: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# W0520 10:42:10.338707 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:2235: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:2236: get_or_create_global_step (from tensorflow.contrib.framework.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.get_or_create_global_step
# W0520 10:42:10.338959 139664952031104 deprecation.py:323] From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:2236: get_or_create_global_step (from tensorflow.contrib.framework.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.get_or_create_global_step
# WARNING:tensorflow:From /content/models/research/object_detection/utils/variables_helper.py:126: The name tf.train.NewCheckpointReader is deprecated. Please use tf.compat.v1.train.NewCheckpointReader instead.
#
# W0520 10:42:10.340017 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/utils/variables_helper.py:126: The name tf.train.NewCheckpointReader is deprecated. Please use tf.compat.v1.train.NewCheckpointReader instead.
#
# W0520 10:42:10.343817 139664952031104 variables_helper.py:141] Variable [SecondStageBoxPredictor/BoxEncodingPredictor/biases] is available in checkpoint, but has an incompatible shape with model variable. Checkpoint shape: [[360]], model variable shape: [[4]]. This variable will not be initialized from the checkpoint.
# W0520 10:42:10.343953 139664952031104 variables_helper.py:141] Variable [SecondStageBoxPredictor/BoxEncodingPredictor/weights] is available in checkpoint, but has an incompatible shape with model variable. Checkpoint shape: [[1024, 360]], model variable shape: [[1024, 4]]. This variable will not be initialized from the checkpoint.
# W0520 10:42:10.344032 139664952031104 variables_helper.py:141] Variable [SecondStageBoxPredictor/ClassPredictor/biases] is available in checkpoint, but has an incompatible shape with model variable. Checkpoint shape: [[91]], model variable shape: [[2]]. This variable will not be initialized from the checkpoint.
# W0520 10:42:10.344105 139664952031104 variables_helper.py:141] Variable [SecondStageBoxPredictor/ClassPredictor/weights] is available in checkpoint, but has an incompatible shape with model variable. Checkpoint shape: [[1024, 91]], model variable shape: [[1024, 2]]. This variable will not be initialized from the checkpoint.
# W0520 10:42:10.344844 139664952031104 variables_helper.py:144] Variable [global_step] is not available in checkpoint
# WARNING:tensorflow:From /content/models/research/object_detection/model_lib.py:317: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# W0520 10:42:10.345055 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/model_lib.py:317: The name tf.train.init_from_checkpoint is deprecated. Please use tf.compat.v1.train.init_from_checkpoint instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/core/losses.py:174: The name tf.losses.huber_loss is deprecated. Please use tf.compat.v1.losses.huber_loss instead.
#
# W0520 10:42:13.545291 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/core/losses.py:174: The name tf.losses.huber_loss is deprecated. Please use tf.compat.v1.losses.huber_loss instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/core/losses.py:180: The name tf.losses.Reduction is deprecated. Please use tf.compat.v1.losses.Reduction instead.
#
# W0520 10:42:13.547056 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/core/losses.py:180: The name tf.losses.Reduction is deprecated. Please use tf.compat.v1.losses.Reduction instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/core/losses.py:345: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W0520 10:42:13.587506 139664952031104 deprecation.py:323] From /content/models/research/object_detection/core/losses.py:345: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# WARNING:tensorflow:From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:2202: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# W0520 10:42:14.921947 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:2202: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/model_lib.py:341: The name tf.train.get_or_create_global_step is deprecated. Please use tf.compat.v1.train.get_or_create_global_step instead.
#
# W0520 10:42:14.922803 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/model_lib.py:341: The name tf.train.get_or_create_global_step is deprecated. Please use tf.compat.v1.train.get_or_create_global_step instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/builders/optimizer_builder.py:52: The name tf.train.MomentumOptimizer is deprecated. Please use tf.compat.v1.train.MomentumOptimizer instead.
#
# W0520 10:42:14.929083 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/builders/optimizer_builder.py:52: The name tf.train.MomentumOptimizer is deprecated. Please use tf.compat.v1.train.MomentumOptimizer instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/model_lib.py:359: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W0520 10:42:14.929297 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/model_lib.py:359: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/model_lib.py:369: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# W0520 10:42:14.929476 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/model_lib.py:369: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# WARNING:tensorflow:From /content/models/research/object_detection/model_lib.py:472: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W0520 10:42:19.742258 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/model_lib.py:472: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/model_lib.py:476: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# W0520 10:42:20.121842 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/model_lib.py:476: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/model_lib.py:477: The name tf.train.Scaffold is deprecated. Please use tf.compat.v1.train.Scaffold instead.
#
# W0520 10:42:20.122130 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/model_lib.py:477: The name tf.train.Scaffold is deprecated. Please use tf.compat.v1.train.Scaffold instead.
#
# INFO:tensorflow:Done calling model_fn.
# I0520 10:42:20.122434 139664952031104 estimator.py:1150] Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# I0520 10:42:20.123560 139664952031104 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# I0520 10:42:23.203250 139664952031104 monitored_session.py:240] Graph was finalized.
# 2021-05-20 10:42:23.203666: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX512F
# 2021-05-20 10:42:23.213203: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000194999 Hz
# 2021-05-20 10:42:23.213506: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55d9bd75f640 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-05-20 10:42:23.213540: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-05-20 10:42:23.326542: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:42:23.327208: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55d9bd75f480 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-05-20 10:42:23.327233: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2021-05-20 10:42:23.327406: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:42:23.327974: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2021-05-20 10:42:23.328056: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-20 10:42:23.328081: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-05-20 10:42:23.328109: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-05-20 10:42:23.328131: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-05-20 10:42:23.328151: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-05-20 10:42:23.328173: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-05-20 10:42:23.328196: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-05-20 10:42:23.328270: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:42:23.328884: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:42:23.329404: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-05-20 10:42:23.332180: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-20 10:42:23.333556: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-05-20 10:42:23.333585: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2021-05-20 10:42:23.333595: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2021-05-20 10:42:23.334624: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:42:23.335240: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:42:23.335794: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-05-20 10:42:23.335836: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14257 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# INFO:tensorflow:Running local_init_op.
# I0520 10:42:33.449522 139664952031104 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0520 10:42:33.811906 139664952031104 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into training/model.ckpt.
# I0520 10:42:43.102452 139664952031104 basic_session_run_hooks.py:606] Saving checkpoints for 0 into training/model.ckpt.
# 2021-05-20 10:42:52.940636: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-05-20 10:42:55.726442: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# INFO:tensorflow:loss = 2.3992639, step = 0
# I0520 10:43:13.005203 139664952031104 basic_session_run_hooks.py:262] loss = 2.3992639, step = 0
# INFO:tensorflow:Saving checkpoints for 3 into training/model.ckpt.
# I0520 10:43:22.233183 139664952031104 basic_session_run_hooks.py:606] Saving checkpoints for 3 into training/model.ckpt.
# WARNING:tensorflow:Entity <function build.<locals>.process_fn at 0x7f057e460ef0> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# W0520 10:43:23.815136 139664952031104 ag_logging.py:146] Entity <function build.<locals>.process_fn at 0x7f057e460ef0> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# INFO:tensorflow:Calling model_fn.
# I0520 10:43:24.240707 139664952031104 estimator.py:1148] Calling model_fn.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0520 10:43:25.603876 139664952031104 regularizers.py:98] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0520 10:43:25.616971 139664952031104 regularizers.py:98] Scale of 0 disables regularizer.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0520 10:43:25.617350 139664952031104 convolutional_box_predictor.py:148] depth of additional conv before box predictor: 0
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0520 10:43:26.545306 139664952031104 regularizers.py:98] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0520 10:43:26.562273 139664952031104 regularizers.py:98] Scale of 0 disables regularizer.
# WARNING:tensorflow:From /content/models/research/object_detection/eval_util.py:750: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0520 10:43:27.491300 139664952031104 deprecation.py:323] From /content/models/research/object_detection/eval_util.py:750: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /content/models/research/object_detection/utils/visualization_utils.py:429: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# W0520 10:43:27.637282 139664952031104 deprecation.py:323] From /content/models/research/object_detection/utils/visualization_utils.py:429: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# WARNING:tensorflow:From /content/models/research/object_detection/utils/visualization_utils.py:924: The name tf.summary.image is deprecated. Please use tf.compat.v1.summary.image instead.
#
# W0520 10:43:27.773011 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/utils/visualization_utils.py:924: The name tf.summary.image is deprecated. Please use tf.compat.v1.summary.image instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/model_lib.py:441: The name tf.metrics.mean is deprecated. Please use tf.compat.v1.metrics.mean instead.
#
# W0520 10:43:27.854766 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/model_lib.py:441: The name tf.metrics.mean is deprecated. Please use tf.compat.v1.metrics.mean instead.
#
# INFO:tensorflow:Done calling model_fn.
# I0520 10:43:28.154211 139664952031104 estimator.py:1150] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-05-20T10:43:28Z
# I0520 10:43:28.169234 139664952031104 evaluation.py:255] Starting evaluation at 2021-05-20T10:43:28Z
# INFO:tensorflow:Graph was finalized.
# I0520 10:43:28.580228 139664952031104 monitored_session.py:240] Graph was finalized.
# 2021-05-20 10:43:28.581352: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:43:28.581722: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2021-05-20 10:43:28.581807: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-20 10:43:28.581834: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-05-20 10:43:28.581857: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-05-20 10:43:28.581881: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-05-20 10:43:28.581904: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-05-20 10:43:28.581924: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-05-20 10:43:28.581947: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-05-20 10:43:28.582033: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:43:28.582370: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:43:28.582662: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-05-20 10:43:28.582702: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-05-20 10:43:28.582716: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2021-05-20 10:43:28.582727: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2021-05-20 10:43:28.582823: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:43:28.583219: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:43:28.583666: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14257 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# INFO:tensorflow:Restoring parameters from training/model.ckpt-3
# I0520 10:43:28.584862 139664952031104 saver.py:1284] Restoring parameters from training/model.ckpt-3
# INFO:tensorflow:Running local_init_op.
# I0520 10:43:29.557388 139664952031104 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0520 10:43:29.703519 139664952031104 session_manager.py:502] Done running local_init_op.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0520 10:43:36.138973 139661347378944 coco_tools.py:109] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.00s)
# I0520 10:43:36.142045 139661347378944 coco_tools.py:131] DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.97s).
# Accumulating evaluation results...
# DONE (t=0.03s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.025
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.172
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.144
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.185
# INFO:tensorflow:Finished evaluation at 2021-05-20-10:43:38
# I0520 10:43:38.243594 139664952031104 evaluation.py:275] Finished evaluation at 2021-05-20-10:43:38
# INFO:tensorflow:Saving dict for global step 3: DetectionBoxes_Precision/mAP = 0.0077950163, DetectionBoxes_Precision/mAP (large) = 0.008064927, DetectionBoxes_Precision/mAP (medium) = 0.0246026, DetectionBoxes_Precision/mAP (small) = -1.0, DetectionBoxes_Precision/mAP@.50IOU = 0.035530027, DetectionBoxes_Precision/mAP@.75IOU = 0.0003457611, DetectionBoxes_Recall/AR@1 = 0.0, DetectionBoxes_Recall/AR@10 = 0.0060913707, DetectionBoxes_Recall/AR@100 = 0.17208122, DetectionBoxes_Recall/AR@100 (large) = 0.18455882, DetectionBoxes_Recall/AR@100 (medium) = 0.1442623, DetectionBoxes_Recall/AR@100 (small) = -1.0, Loss/BoxClassifierLoss/classification_loss = 0.6945222, Loss/BoxClassifierLoss/localization_loss = 0.44108263, Loss/RPNLoss/localization_loss = 0.3756316, Loss/RPNLoss/objectness_loss = 0.7844162, Loss/total_loss = 2.2956529, global_step = 3, learning_rate = 0.0002, loss = 2.2956529
# I0520 10:43:38.243880 139664952031104 estimator.py:2049] Saving dict for global step 3: DetectionBoxes_Precision/mAP = 0.0077950163, DetectionBoxes_Precision/mAP (large) = 0.008064927, DetectionBoxes_Precision/mAP (medium) = 0.0246026, DetectionBoxes_Precision/mAP (small) = -1.0, DetectionBoxes_Precision/mAP@.50IOU = 0.035530027, DetectionBoxes_Precision/mAP@.75IOU = 0.0003457611, DetectionBoxes_Recall/AR@1 = 0.0, DetectionBoxes_Recall/AR@10 = 0.0060913707, DetectionBoxes_Recall/AR@100 = 0.17208122, DetectionBoxes_Recall/AR@100 (large) = 0.18455882, DetectionBoxes_Recall/AR@100 (medium) = 0.1442623, DetectionBoxes_Recall/AR@100 (small) = -1.0, Loss/BoxClassifierLoss/classification_loss = 0.6945222, Loss/BoxClassifierLoss/localization_loss = 0.44108263, Loss/RPNLoss/localization_loss = 0.3756316, Loss/RPNLoss/objectness_loss = 0.7844162, Loss/total_loss = 2.2956529, global_step = 3, learning_rate = 0.0002, loss = 2.2956529
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3: training/model.ckpt-3
# I0520 10:43:39.130665 139664952031104 estimator.py:2109] Saving 'checkpoint_path' summary for global step 3: training/model.ckpt-3
# INFO:tensorflow:Performing the final export in the end of training.
# I0520 10:43:39.131536 139664952031104 exporter.py:410] Performing the final export in the end of training.
# WARNING:tensorflow:From /content/models/research/object_detection/inputs.py:606: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0520 10:43:39.136936 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/inputs.py:606: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# INFO:tensorflow:Calling model_fn.
# I0520 10:43:39.293947 139664952031104 estimator.py:1148] Calling model_fn.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0520 10:43:41.015412 139664952031104 regularizers.py:98] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0520 10:43:41.029195 139664952031104 regularizers.py:98] Scale of 0 disables regularizer.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0520 10:43:41.029599 139664952031104 convolutional_box_predictor.py:148] depth of additional conv before box predictor: 0
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0520 10:43:41.992493 139664952031104 regularizers.py:98] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0520 10:43:42.009401 139664952031104 regularizers.py:98] Scale of 0 disables regularizer.
# WARNING:tensorflow:From /content/models/research/object_detection/model_lib.py:387: The name tf.saved_model.signature_constants.PREDICT_METHOD_NAME is deprecated. Please use tf.saved_model.PREDICT_METHOD_NAME instead.
#
# W0520 10:43:42.493807 139664952031104 module_wrapper.py:139] From /content/models/research/object_detection/model_lib.py:387: The name tf.saved_model.signature_constants.PREDICT_METHOD_NAME is deprecated. Please use tf.saved_model.PREDICT_METHOD_NAME instead.
#
# INFO:tensorflow:Done calling model_fn.
# I0520 10:43:42.743237 139664952031104 estimator.py:1150] Done calling model_fn.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# W0520 10:43:42.743552 139664952031104 deprecation.py:323] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# I0520 10:43:42.744015 139664952031104 export_utils.py:170] Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# I0520 10:43:42.744131 139664952031104 export_utils.py:170] Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['tensorflow/serving/predict', 'serving_default']
# I0520 10:43:42.744217 139664952031104 export_utils.py:170] Signatures INCLUDED in export for Predict: ['tensorflow/serving/predict', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# I0520 10:43:42.744288 139664952031104 export_utils.py:170] Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# I0520 10:43:42.744356 139664952031104 export_utils.py:170] Signatures INCLUDED in export for Eval: None
# 2021-05-20 10:43:42.744899: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:43:42.745278: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2021-05-20 10:43:42.745358: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-20 10:43:42.745382: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-05-20 10:43:42.745404: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-05-20 10:43:42.745427: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-05-20 10:43:42.745452: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-05-20 10:43:42.745472: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-05-20 10:43:42.745509: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-05-20 10:43:42.745599: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:43:42.745952: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:43:42.746227: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-05-20 10:43:42.746269: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-05-20 10:43:42.746283: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2021-05-20 10:43:42.746292: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2021-05-20 10:43:42.746387: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:43:42.746743: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:43:42.747041: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14257 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# INFO:tensorflow:Restoring parameters from training/model.ckpt-3
# I0520 10:43:42.749294 139664952031104 saver.py:1284] Restoring parameters from training/model.ckpt-3
# INFO:tensorflow:Assets added to graph.
# I0520 10:43:43.256329 139664952031104 builder_impl.py:665] Assets added to graph.
# INFO:tensorflow:No assets to write.
# I0520 10:43:43.256581 139664952031104 builder_impl.py:460] No assets to write.
# INFO:tensorflow:SavedModel written to: training/export/Servo/temp-b'1621507419'/saved_model.pb
# I0520 10:43:44.068093 139664952031104 builder_impl.py:425] SavedModel written to: training/export/Servo/temp-b'1621507419'/saved_model.pb
# INFO:tensorflow:Loss for final step: 2.870542.
# I0520 10:43:44.445336 139664952031104 estimator.py:371] Loss for final step: 2.870542.

# %%
# !ls {model_dir}
# Out:
# checkpoint				     model.ckpt-0.index
# eval_0					     model.ckpt-0.meta
# events.out.tfevents.1621507341.24e31d4fb5cc  model.ckpt-3.data-00000-of-00001
# export					     model.ckpt-3.index
# graph.pbtxt				     model.ckpt-3.meta
# model.ckpt-0.data-00000-of-00001

# %% [markdown]
# ##Task-4:  Freezing a trained model and export it for inference

# %% [markdown]
# ### Step: 10 Exporting a Trained Inference Graph

# %%
import re
import numpy as np

output_directory = './fine_tuned_model'

lst = os.listdir(model_dir)
lst = [l for l in lst if 'model.ckpt-' in l and '.meta' in l]
steps=np.array([int(re.findall('\d+', l)[0]) for l in lst])
last_model = lst[steps.argmax()].replace('.meta', '')

last_model_path = os.path.join(model_dir, last_model)
print(last_model_path)
# !python /content/models/research/object_detection/export_inference_graph.py \
    --input_type=image_tensor \
    --pipeline_config_path={pipeline_fname} \
    --output_directory={output_directory} \
    --trained_checkpoint_prefix={last_model_path}
# Out:
# training/model.ckpt-3
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/models/research/slim/nets/inception_resnet_v2.py:373: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/models/research/slim/nets/mobilenet/mobilenet.py:389: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/export_inference_graph.py:150: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/export_inference_graph.py:133: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0520 10:43:49.116891 140141735913344 module_wrapper.py:139] From /content/models/research/object_detection/export_inference_graph.py:133: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/anchor_generators/grid_anchor_generator.py:59: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0520 10:43:49.120876 140141735913344 deprecation.py:323] From /content/models/research/object_detection/anchor_generators/grid_anchor_generator.py:59: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /content/models/research/object_detection/exporter.py:348: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# W0520 10:43:49.123913 140141735913344 module_wrapper.py:139] From /content/models/research/object_detection/exporter.py:348: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/exporter.py:113: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0520 10:43:49.124220 140141735913344 module_wrapper.py:139] From /content/models/research/object_detection/exporter.py:113: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/core/preprocessor.py:2154: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0520 10:43:49.161619 140141735913344 deprecation.py:323] From /content/models/research/object_detection/core/preprocessor.py:2154: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /content/models/research/object_detection/core/preprocessor.py:2236: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# W0520 10:43:49.176530 140141735913344 module_wrapper.py:139] From /content/models/research/object_detection/core/preprocessor.py:2236: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:162: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0520 10:43:49.201503 140141735913344 module_wrapper.py:139] From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:162: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/contrib/layers/python/layers/layers.py:2784: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W0520 10:43:49.212351 140141735913344 deprecation.py:323] From /tensorflow-1.15.2/python3.7/tensorflow_core/contrib/layers/python/layers/layers.py:2784: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /content/models/research/object_detection/core/anchor_generator.py:149: The name tf.assert_equal is deprecated. Please use tf.compat.v1.assert_equal instead.
#
# W0520 10:43:50.659532 140141735913344 module_wrapper.py:139] From /content/models/research/object_detection/core/anchor_generator.py:149: The name tf.assert_equal is deprecated. Please use tf.compat.v1.assert_equal instead.
#
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0520 10:43:50.666019 140141735913344 regularizers.py:98] Scale of 0 disables regularizer.
# WARNING:tensorflow:From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:986: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# W0520 10:43:50.666405 140141735913344 module_wrapper.py:139] From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:986: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0520 10:43:50.679595 140141735913344 regularizers.py:98] Scale of 0 disables regularizer.
# WARNING:tensorflow:From /content/models/research/object_detection/predictors/convolutional_box_predictor.py:147: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# W0520 10:43:50.680014 140141735913344 module_wrapper.py:139] From /content/models/research/object_detection/predictors/convolutional_box_predictor.py:147: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0520 10:43:50.680140 140141735913344 convolutional_box_predictor.py:148] depth of additional conv before box predictor: 0
# WARNING:tensorflow:From /content/models/research/object_detection/core/box_list_ops.py:136: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0520 10:43:50.735434 140141735913344 deprecation.py:323] From /content/models/research/object_detection/core/box_list_ops.py:136: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/models/research/object_detection/utils/ops.py:1085: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# W0520 10:43:51.161438 140141735913344 deprecation.py:506] From /content/models/research/object_detection/utils/ops.py:1085: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# WARNING:tensorflow:From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:185: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# W0520 10:43:51.178055 140141735913344 module_wrapper.py:139] From /content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:185: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/contrib/layers/python/layers/layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# W0520 10:43:51.645677 140141735913344 deprecation.py:323] From /tensorflow-1.15.2/python3.7/tensorflow_core/contrib/layers/python/layers/layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0520 10:43:51.650895 140141735913344 regularizers.py:98] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0520 10:43:51.669139 140141735913344 regularizers.py:98] Scale of 0 disables regularizer.
# WARNING:tensorflow:From /content/models/research/object_detection/exporter.py:231: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# W0520 10:43:52.304384 140141735913344 module_wrapper.py:139] From /content/models/research/object_detection/exporter.py:231: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/exporter.py:330: get_or_create_global_step (from tensorflow.contrib.framework.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.get_or_create_global_step
# W0520 10:43:52.304676 140141735913344 deprecation.py:323] From /content/models/research/object_detection/exporter.py:330: get_or_create_global_step (from tensorflow.contrib.framework.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.get_or_create_global_step
# WARNING:tensorflow:From /content/models/research/object_detection/exporter.py:361: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0520 10:43:52.307543 140141735913344 module_wrapper.py:139] From /content/models/research/object_detection/exporter.py:361: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/exporter.py:484: print_model_analysis (from tensorflow.contrib.tfprof.model_analyzer) is deprecated and will be removed after 2018-01-01.
# Instructions for updating:
# Use `tf.profiler.profile(graph, run_meta, op_log, cmd, options)`. Build `options` with `tf.profiler.ProfileOptionBuilder`. See README.md for details
# W0520 10:43:52.307721 140141735913344 deprecation.py:323] From /content/models/research/object_detection/exporter.py:484: print_model_analysis (from tensorflow.contrib.tfprof.model_analyzer) is deprecated and will be removed after 2018-01-01.
# Instructions for updating:
# Use `tf.profiler.profile(graph, run_meta, op_log, cmd, options)`. Build `options` with `tf.profiler.ProfileOptionBuilder`. See README.md for details
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/profiler/internal/flops_registry.py:142: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# W0520 10:43:52.308762 140141735913344 deprecation.py:323] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/profiler/internal/flops_registry.py:142: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# 225 ops no flops stats due to incomplete shapes.
# Parsing Inputs...
# Incomplete shape.
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              0
# -min_occurrence             0
# -step                       -1
# -order_by                   name
# -account_type_regexes       _trainable_variables
# -start_name_regexes         .*
# -trim_name_regexes          .*BatchNorm.*
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     params
# -output                     stdout:
#
# ==================Model Analysis Report======================
# Incomplete shape.
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# param: Number of parameters (in the Variable).
#
# Profile:
# node name | # parameters
# _TFProfRoot (--/12.84m params)
#   Conv (--/2.65m params)
#     Conv/biases (512, 512/512 params)
#     Conv/weights (3x3x576x512, 2.65m/2.65m params)
#   FirstStageBoxPredictor (--/36.94k params)
#     FirstStageBoxPredictor/BoxEncodingPredictor (--/24.62k params)
#       FirstStageBoxPredictor/BoxEncodingPredictor/biases (48, 48/48 params)
#       FirstStageBoxPredictor/BoxEncodingPredictor/weights (1x1x512x48, 24.58k/24.58k params)
#     FirstStageBoxPredictor/ClassPredictor (--/12.31k params)
#       FirstStageBoxPredictor/ClassPredictor/biases (24, 24/24 params)
#       FirstStageBoxPredictor/ClassPredictor/weights (1x1x512x24, 12.29k/12.29k params)
#   FirstStageFeatureExtractor (--/4.25m params)
#     FirstStageFeatureExtractor/InceptionV2 (--/4.25m params)
#       FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7 (--/2.71k params)
#         FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/BatchNorm (--/0 params)
#         FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/depthwise_weights (7x7x3x8, 1.18k/1.18k params)
#         FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/pointwise_weights (1x1x24x64, 1.54k/1.54k params)
#       FirstStageFeatureExtractor/InceptionV2/Conv2d_2b_1x1 (--/4.10k params)
#         FirstStageFeatureExtractor/InceptionV2/Conv2d_2b_1x1/BatchNorm (--/0 params)
#         FirstStageFeatureExtractor/InceptionV2/Conv2d_2b_1x1/weights (1x1x64x64, 4.10k/4.10k params)
#       FirstStageFeatureExtractor/InceptionV2/Conv2d_2c_3x3 (--/110.59k params)
#         FirstStageFeatureExtractor/InceptionV2/Conv2d_2c_3x3/BatchNorm (--/0 params)
#         FirstStageFeatureExtractor/InceptionV2/Conv2d_2c_3x3/weights (3x3x64x192, 110.59k/110.59k params)
#       FirstStageFeatureExtractor/InceptionV2/Mixed_3b (--/218.11k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_0 (--/12.29k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1 (--/12.29k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/weights (1x1x192x64, 12.29k/12.29k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1 (--/49.15k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1 (--/12.29k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/weights (1x1x192x64, 12.29k/12.29k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3 (--/36.86k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/weights (3x3x64x64, 36.86k/36.86k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2 (--/150.53k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1 (--/12.29k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/weights (1x1x192x64, 12.29k/12.29k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3 (--/55.30k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/weights (3x3x64x96, 55.30k/55.30k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0c_3x3 (--/82.94k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0c_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0c_3x3/weights (3x3x96x96, 82.94k/82.94k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_3 (--/6.14k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_3/Conv2d_0b_1x1 (--/6.14k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_3/Conv2d_0b_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_3/Conv2d_0b_1x1/weights (1x1x192x32, 6.14k/6.14k params)
#       FirstStageFeatureExtractor/InceptionV2/Mixed_3c (--/259.07k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_0 (--/16.38k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_0/Conv2d_0a_1x1 (--/16.38k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_0/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_0/Conv2d_0a_1x1/weights (1x1x256x64, 16.38k/16.38k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_1 (--/71.68k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_1/Conv2d_0a_1x1 (--/16.38k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_1/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_1/Conv2d_0a_1x1/weights (1x1x256x64, 16.38k/16.38k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_1/Conv2d_0b_3x3 (--/55.30k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_1/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_1/Conv2d_0b_3x3/weights (3x3x64x96, 55.30k/55.30k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_2 (--/154.62k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_2/Conv2d_0a_1x1 (--/16.38k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_2/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_2/Conv2d_0a_1x1/weights (1x1x256x64, 16.38k/16.38k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_2/Conv2d_0b_3x3 (--/55.30k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_2/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_2/Conv2d_0b_3x3/weights (3x3x64x96, 55.30k/55.30k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_2/Conv2d_0c_3x3 (--/82.94k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_2/Conv2d_0c_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_2/Conv2d_0c_3x3/weights (3x3x96x96, 82.94k/82.94k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_3 (--/16.38k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_3/Conv2d_0b_1x1 (--/16.38k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_3/Conv2d_0b_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_3c/Branch_3/Conv2d_0b_1x1/weights (1x1x256x64, 16.38k/16.38k params)
#       FirstStageFeatureExtractor/InceptionV2/Mixed_4a (--/384.00k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_0 (--/225.28k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_0/Conv2d_0a_1x1 (--/40.96k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_0/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_0/Conv2d_0a_1x1/weights (1x1x320x128, 40.96k/40.96k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_0/Conv2d_1a_3x3 (--/184.32k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_0/Conv2d_1a_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_0/Conv2d_1a_3x3/weights (3x3x128x160, 184.32k/184.32k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_1 (--/158.72k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_1/Conv2d_0a_1x1 (--/20.48k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_1/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_1/Conv2d_0a_1x1/weights (1x1x320x64, 20.48k/20.48k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_1/Conv2d_0b_3x3 (--/55.30k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_1/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_1/Conv2d_0b_3x3/weights (3x3x64x96, 55.30k/55.30k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_1/Conv2d_1a_3x3 (--/82.94k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_1/Conv2d_1a_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4a/Branch_1/Conv2d_1a_3x3/weights (3x3x96x96, 82.94k/82.94k params)
#       FirstStageFeatureExtractor/InceptionV2/Mixed_4b (--/608.26k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_0 (--/129.02k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_0/Conv2d_0a_1x1 (--/129.02k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_0/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_0/Conv2d_0a_1x1/weights (1x1x576x224, 129.02k/129.02k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_1 (--/92.16k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_1/Conv2d_0a_1x1 (--/36.86k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_1/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_1/Conv2d_0a_1x1/weights (1x1x576x64, 36.86k/36.86k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_1/Conv2d_0b_3x3 (--/55.30k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_1/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_1/Conv2d_0b_3x3/weights (3x3x64x96, 55.30k/55.30k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_2 (--/313.34k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_2/Conv2d_0a_1x1 (--/55.30k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_2/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_2/Conv2d_0a_1x1/weights (1x1x576x96, 55.30k/55.30k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_2/Conv2d_0b_3x3 (--/110.59k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_2/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_2/Conv2d_0b_3x3/weights (3x3x96x128, 110.59k/110.59k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_2/Conv2d_0c_3x3 (--/147.46k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_2/Conv2d_0c_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_2/Conv2d_0c_3x3/weights (3x3x128x128, 147.46k/147.46k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_3 (--/73.73k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_3/Conv2d_0b_1x1 (--/73.73k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_3/Conv2d_0b_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4b/Branch_3/Conv2d_0b_1x1/weights (1x1x576x128, 73.73k/73.73k params)
#       FirstStageFeatureExtractor/InceptionV2/Mixed_4c (--/663.55k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_0 (--/110.59k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_0/Conv2d_0a_1x1 (--/110.59k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_0/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_0/Conv2d_0a_1x1/weights (1x1x576x192, 110.59k/110.59k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_1 (--/165.89k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_1/Conv2d_0a_1x1 (--/55.30k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_1/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_1/Conv2d_0a_1x1/weights (1x1x576x96, 55.30k/55.30k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_1/Conv2d_0b_3x3 (--/110.59k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_1/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_1/Conv2d_0b_3x3/weights (3x3x96x128, 110.59k/110.59k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_2 (--/313.34k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_2/Conv2d_0a_1x1 (--/55.30k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_2/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_2/Conv2d_0a_1x1/weights (1x1x576x96, 55.30k/55.30k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_2/Conv2d_0b_3x3 (--/110.59k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_2/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_2/Conv2d_0b_3x3/weights (3x3x96x128, 110.59k/110.59k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_2/Conv2d_0c_3x3 (--/147.46k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_2/Conv2d_0c_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_2/Conv2d_0c_3x3/weights (3x3x128x128, 147.46k/147.46k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_3 (--/73.73k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_3/Conv2d_0b_1x1 (--/73.73k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_3/Conv2d_0b_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4c/Branch_3/Conv2d_0b_1x1/weights (1x1x576x128, 73.73k/73.73k params)
#       FirstStageFeatureExtractor/InceptionV2/Mixed_4d (--/893.95k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_0 (--/92.16k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_0/Conv2d_0a_1x1 (--/92.16k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_0/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_0/Conv2d_0a_1x1/weights (1x1x576x160, 92.16k/92.16k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_1 (--/258.05k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_1/Conv2d_0a_1x1 (--/73.73k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_1/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_1/Conv2d_0a_1x1/weights (1x1x576x128, 73.73k/73.73k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_1/Conv2d_0b_3x3 (--/184.32k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_1/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_1/Conv2d_0b_3x3/weights (3x3x128x160, 184.32k/184.32k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_2 (--/488.45k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_2/Conv2d_0a_1x1 (--/73.73k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_2/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_2/Conv2d_0a_1x1/weights (1x1x576x128, 73.73k/73.73k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_2/Conv2d_0b_3x3 (--/184.32k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_2/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_2/Conv2d_0b_3x3/weights (3x3x128x160, 184.32k/184.32k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_2/Conv2d_0c_3x3 (--/230.40k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_2/Conv2d_0c_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_2/Conv2d_0c_3x3/weights (3x3x160x160, 230.40k/230.40k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_3 (--/55.30k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_3/Conv2d_0b_1x1 (--/55.30k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_3/Conv2d_0b_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4d/Branch_3/Conv2d_0b_1x1/weights (1x1x576x96, 55.30k/55.30k params)
#       FirstStageFeatureExtractor/InceptionV2/Mixed_4e (--/1.11m params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_0 (--/55.30k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_0/Conv2d_0a_1x1 (--/55.30k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_0/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_0/Conv2d_0a_1x1/weights (1x1x576x96, 55.30k/55.30k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_1 (--/294.91k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_1/Conv2d_0a_1x1 (--/73.73k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_1/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_1/Conv2d_0a_1x1/weights (1x1x576x128, 73.73k/73.73k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_1/Conv2d_0b_3x3 (--/221.18k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_1/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_1/Conv2d_0b_3x3/weights (3x3x128x192, 221.18k/221.18k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_2 (--/700.42k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_2/Conv2d_0a_1x1 (--/92.16k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_2/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_2/Conv2d_0a_1x1/weights (1x1x576x160, 92.16k/92.16k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_2/Conv2d_0b_3x3 (--/276.48k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_2/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_2/Conv2d_0b_3x3/weights (3x3x160x192, 276.48k/276.48k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_2/Conv2d_0c_3x3 (--/331.78k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_2/Conv2d_0c_3x3/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_2/Conv2d_0c_3x3/weights (3x3x192x192, 331.78k/331.78k params)
#         FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_3 (--/55.30k params)
#           FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_3/Conv2d_0b_1x1 (--/55.30k params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_3/Conv2d_0b_1x1/BatchNorm (--/0 params)
#             FirstStageFeatureExtractor/InceptionV2/Mixed_4e/Branch_3/Conv2d_0b_1x1/weights (1x1x576x96, 55.30k/55.30k params)
#   SecondStageBoxPredictor (--/6.15k params)
#     SecondStageBoxPredictor/BoxEncodingPredictor (--/4.10k params)
#       SecondStageBoxPredictor/BoxEncodingPredictor/biases (4, 4/4 params)
#       SecondStageBoxPredictor/BoxEncodingPredictor/weights (1024x4, 4.10k/4.10k params)
#     SecondStageBoxPredictor/ClassPredictor (--/2.05k params)
#       SecondStageBoxPredictor/ClassPredictor/biases (2, 2/2 params)
#       SecondStageBoxPredictor/ClassPredictor/weights (1024x2, 2.05k/2.05k params)
#   SecondStageFeatureExtractor (--/5.89m params)
#     SecondStageFeatureExtractor/InceptionV2 (--/5.89m params)
#       SecondStageFeatureExtractor/InceptionV2/Mixed_5a (--/1.44m params)
#         SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_0 (--/294.91k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_0/Conv2d_0a_1x1 (--/73.73k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_0/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_0/Conv2d_0a_1x1/weights (1x1x576x128, 73.73k/73.73k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_0/Conv2d_1a_3x3 (--/221.18k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_0/Conv2d_1a_3x3/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_0/Conv2d_1a_3x3/weights (3x3x128x192, 221.18k/221.18k params)
#         SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_1 (--/1.14m params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_1/Conv2d_0a_1x1 (--/110.59k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_1/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_1/Conv2d_0a_1x1/weights (1x1x576x192, 110.59k/110.59k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_1/Conv2d_0b_3x3 (--/442.37k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_1/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_1/Conv2d_0b_3x3/weights (3x3x192x256, 442.37k/442.37k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_1/Conv2d_1a_3x3 (--/589.82k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_1/Conv2d_1a_3x3/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5a/Branch_1/Conv2d_1a_3x3/weights (3x3x256x256, 589.82k/589.82k params)
#       SecondStageFeatureExtractor/InceptionV2/Mixed_5b (--/2.18m params)
#         SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_0 (--/360.45k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_0/Conv2d_0a_1x1 (--/360.45k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_0/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_0/Conv2d_0a_1x1/weights (1x1x1024x352, 360.45k/360.45k params)
#         SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_1 (--/749.57k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_1/Conv2d_0a_1x1 (--/196.61k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_1/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_1/Conv2d_0a_1x1/weights (1x1x1024x192, 196.61k/196.61k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_1/Conv2d_0b_3x3 (--/552.96k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_1/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_1/Conv2d_0b_3x3/weights (3x3x192x320, 552.96k/552.96k params)
#         SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_2 (--/937.98k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_2/Conv2d_0a_1x1 (--/163.84k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_2/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_2/Conv2d_0a_1x1/weights (1x1x1024x160, 163.84k/163.84k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_2/Conv2d_0b_3x3 (--/322.56k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_2/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_2/Conv2d_0b_3x3/weights (3x3x160x224, 322.56k/322.56k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_2/Conv2d_0c_3x3 (--/451.58k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_2/Conv2d_0c_3x3/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_2/Conv2d_0c_3x3/weights (3x3x224x224, 451.58k/451.58k params)
#         SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_3 (--/131.07k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_3/Conv2d_0b_1x1 (--/131.07k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_3/Conv2d_0b_1x1/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5b/Branch_3/Conv2d_0b_1x1/weights (1x1x1024x128, 131.07k/131.07k params)
#       SecondStageFeatureExtractor/InceptionV2/Mixed_5c (--/2.28m params)
#         SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_0 (--/360.45k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_0/Conv2d_0a_1x1 (--/360.45k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_0/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_0/Conv2d_0a_1x1/weights (1x1x1024x352, 360.45k/360.45k params)
#         SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_1 (--/749.57k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_1/Conv2d_0a_1x1 (--/196.61k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_1/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_1/Conv2d_0a_1x1/weights (1x1x1024x192, 196.61k/196.61k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_1/Conv2d_0b_3x3 (--/552.96k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_1/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_1/Conv2d_0b_3x3/weights (3x3x192x320, 552.96k/552.96k params)
#         SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_2 (--/1.04m params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_2/Conv2d_0a_1x1 (--/196.61k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_2/Conv2d_0a_1x1/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_2/Conv2d_0a_1x1/weights (1x1x1024x192, 196.61k/196.61k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_2/Conv2d_0b_3x3 (--/387.07k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_2/Conv2d_0b_3x3/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_2/Conv2d_0b_3x3/weights (3x3x192x224, 387.07k/387.07k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_2/Conv2d_0c_3x3 (--/451.58k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_2/Conv2d_0c_3x3/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_2/Conv2d_0c_3x3/weights (3x3x224x224, 451.58k/451.58k params)
#         SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_3 (--/131.07k params)
#           SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_3/Conv2d_0b_1x1 (--/131.07k params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_3/Conv2d_0b_1x1/BatchNorm (--/0 params)
#             SecondStageFeatureExtractor/InceptionV2/Mixed_5c/Branch_3/Conv2d_0b_1x1/weights (1x1x1024x128, 131.07k/131.07k params)
#
# ======================End of Report==========================
# 225 ops no flops stats due to incomplete shapes.
# Parsing Inputs...
# Incomplete shape.
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes          .*BatchNorm.*,.*Initializer.*,.*Regularizer.*,.*BiasAdd.*
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
# Incomplete shape.
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/2.54k flops)
#   map_1/while/mul_3 (300/300 flops)
#   map_1/while/mul_2 (300/300 flops)
#   map_1/while/mul_1 (300/300 flops)
#   map_1/while/mul (300/300 flops)
#   map/while/ToNormalizedCoordinates/Scale/mul_3 (300/300 flops)
#   map/while/ToNormalizedCoordinates/Scale/mul_2 (300/300 flops)
#   map/while/ToNormalizedCoordinates/Scale/mul_1 (300/300 flops)
#   map/while/ToNormalizedCoordinates/Scale/mul (300/300 flops)
#   GridAnchorGenerator/mul (12/12 flops)
#   GridAnchorGenerator/mul_1 (12/12 flops)
#   GridAnchorGenerator/mul_2 (12/12 flops)
#   GridAnchorGenerator/truediv (12/12 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Minimum (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_1 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_2 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_3 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_4 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_5 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/SortByField_1/Equal (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/SortByField/Equal (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Minimum_1 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_11 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Greater (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame/truediv_1 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame/truediv (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame/sub_1 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame/sub (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/Less_1 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_6 (1/1 flops)
#   mul (1/1 flops)
#   map_1/while/Less_1 (1/1 flops)
#   map_1/while/Less (1/1 flops)
#   map/while/ToNormalizedCoordinates/truediv_1 (1/1 flops)
#   map/while/ToNormalizedCoordinates/truediv (1/1 flops)
#   map/while/Less_1 (1/1 flops)
#   map/while/Less (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_9 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_8 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_7 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_6 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_5 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_4 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_3 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_2 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_13 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_12 (1/1 flops)
#   Preprocessor/map/while/ResizeToRange/truediv_1 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_10 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_1 (1/1 flops)
#   SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_4 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_4 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_3 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_2 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_13 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_12 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_11 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_10 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_1 (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub (1/1 flops)
#   BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_6 (1/1 flops)
# ...
# 2021-05-20 10:43:54.350742: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:43:54.351444: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55d89e596540 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-05-20 10:43:54.351475: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2021-05-20 10:43:54.351694: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:43:54.352211: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2021-05-20 10:43:54.352273: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-20 10:43:54.352297: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-05-20 10:43:54.352320: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-05-20 10:43:54.352340: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-05-20 10:43:54.352359: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-05-20 10:43:54.352377: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-05-20 10:43:54.352397: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-05-20 10:43:54.352466: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:43:54.353043: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:43:54.353552: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-05-20 10:43:54.353621: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-20 10:43:54.354753: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-05-20 10:43:54.354778: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2021-05-20 10:43:54.354789: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2021-05-20 10:43:54.354898: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:43:54.355441: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:43:54.355953: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-05-20 10:43:54.356000: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14257 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# INFO:tensorflow:Restoring parameters from training/model.ckpt-3
# I0520 10:43:54.357594 140141735913344 saver.py:1284] Restoring parameters from training/model.ckpt-3
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/tools/freeze_graph.py:127: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# W0520 10:43:56.018290 140141735913344 deprecation.py:323] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/tools/freeze_graph.py:127: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# 2021-05-20 10:43:56.503182: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:43:56.503811: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2021-05-20 10:43:56.503898: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-20 10:43:56.503931: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-05-20 10:43:56.503955: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-05-20 10:43:56.503977: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-05-20 10:43:56.503996: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-05-20 10:43:56.504016: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-05-20 10:43:56.504036: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-05-20 10:43:56.504140: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:43:56.504722: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:43:56.505212: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-05-20 10:43:56.505253: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-05-20 10:43:56.505267: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2021-05-20 10:43:56.505278: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2021-05-20 10:43:56.505374: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:43:56.505929: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:43:56.506434: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14257 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# INFO:tensorflow:Restoring parameters from training/model.ckpt-3
# I0520 10:43:56.507499 140141735913344 saver.py:1284] Restoring parameters from training/model.ckpt-3
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/tools/freeze_graph.py:233: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# W0520 10:43:57.203572 140141735913344 deprecation.py:323] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/tools/freeze_graph.py:233: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/framework/graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# W0520 10:43:57.203854 140141735913344 deprecation.py:323] From /tensorflow-1.15.2/python3.7/tensorflow_core/python/framework/graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# INFO:tensorflow:Froze 356 variables.
# I0520 10:43:57.584729 140141735913344 graph_util_impl.py:334] Froze 356 variables.
# INFO:tensorflow:Converted 356 variables to const ops.
# I0520 10:43:57.681869 140141735913344 graph_util_impl.py:394] Converted 356 variables to const ops.
# 2021-05-20 10:43:57.880430: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:43:57.881051: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2021-05-20 10:43:57.881142: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-20 10:43:57.881168: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-05-20 10:43:57.881192: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-05-20 10:43:57.881213: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-05-20 10:43:57.881234: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-05-20 10:43:57.881254: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-05-20 10:43:57.881275: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-05-20 10:43:57.881383: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:43:57.881978: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:43:57.882504: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-05-20 10:43:57.882546: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-05-20 10:43:57.882560: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2021-05-20 10:43:57.882570: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2021-05-20 10:43:57.882673: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:43:57.883209: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-20 10:43:57.883722: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14257 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# WARNING:tensorflow:From /content/models/research/object_detection/exporter.py:259: The name tf.saved_model.builder.SavedModelBuilder is deprecated. Please use tf.compat.v1.saved_model.builder.SavedModelBuilder instead.
#
# W0520 10:43:58.245432 140141735913344 module_wrapper.py:139] From /content/models/research/object_detection/exporter.py:259: The name tf.saved_model.builder.SavedModelBuilder is deprecated. Please use tf.compat.v1.saved_model.builder.SavedModelBuilder instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/exporter.py:262: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# W0520 10:43:58.245943 140141735913344 deprecation.py:323] From /content/models/research/object_detection/exporter.py:262: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# WARNING:tensorflow:From /content/models/research/object_detection/exporter.py:268: The name tf.saved_model.signature_def_utils.build_signature_def is deprecated. Please use tf.compat.v1.saved_model.signature_def_utils.build_signature_def instead.
#
# W0520 10:43:58.246307 140141735913344 module_wrapper.py:139] From /content/models/research/object_detection/exporter.py:268: The name tf.saved_model.signature_def_utils.build_signature_def is deprecated. Please use tf.compat.v1.saved_model.signature_def_utils.build_signature_def instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/exporter.py:274: The name tf.saved_model.tag_constants.SERVING is deprecated. Please use tf.saved_model.SERVING instead.
#
# W0520 10:43:58.246560 140141735913344 module_wrapper.py:139] From /content/models/research/object_detection/exporter.py:274: The name tf.saved_model.tag_constants.SERVING is deprecated. Please use tf.saved_model.SERVING instead.
#
# INFO:tensorflow:No assets to save.
# I0520 10:43:58.246836 140141735913344 builder_impl.py:640] No assets to save.
# INFO:tensorflow:No assets to write.
# I0520 10:43:58.246929 140141735913344 builder_impl.py:460] No assets to write.
# INFO:tensorflow:SavedModel written to: ./fine_tuned_model/saved_model/saved_model.pb
# I0520 10:43:58.590501 140141735913344 builder_impl.py:425] SavedModel written to: ./fine_tuned_model/saved_model/saved_model.pb
# WARNING:tensorflow:From /content/models/research/object_detection/utils/config_util.py:180: The name tf.gfile.Open is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0520 10:43:58.630284 140141735913344 module_wrapper.py:139] From /content/models/research/object_detection/utils/config_util.py:180: The name tf.gfile.Open is deprecated. Please use tf.io.gfile.GFile instead.
#
# INFO:tensorflow:Writing pipeline config file to ./fine_tuned_model/pipeline.config
# I0520 10:43:58.630593 140141735913344 config_util.py:182] Writing pipeline config file to ./fine_tuned_model/pipeline.config

# %%
# !ls {output_directory}
# Out:
# checkpoint			model.ckpt.index  saved_model
# frozen_inference_graph.pb	model.ckpt.meta
# model.ckpt.data-00000-of-00001	pipeline.config

# %% [markdown]
# ### Step 11: Use frozen model for inference.

# %%
import os

pb_fname = os.path.join(os.path.abspath(output_directory), "frozen_inference_graph.pb")
assert os.path.isfile(pb_fname), '`{}` not exist'.format(pb_fname)

# %%
# !ls -alh {pb_fname}
# Out:
# -rw-r--r-- 1 root root 50M May 20 10:43 /content/models/research/fine_tuned_model/frozen_inference_graph.pb

# %%
#Put two test files in '/content/object_detection_demo/'
#!mv "/content/object_detection_demo/data/images/test/BloodImage_00059.jpeg" "/content/object_detection_demo/test"
#!mv "/content/object_detection_demo/data/images/test/BloodImage_00095.jpeg" "/content/object_detection_demo/test"
repo_dir_path='/content/object_detection_demo/data/images/'

# %%
import os
import glob

# Path to frozen detection graph. This is the actual model that is used for the object detection.
PATH_TO_CKPT = pb_fname

# List of the strings that is used to add correct label for each box.
PATH_TO_LABELS = label_map_pbtxt_fname

# If you want to test the code with your images, just add images files to the PATH_TO_TEST_IMAGES_DIR.
PATH_TO_TEST_IMAGES_DIR =  os.path.join(repo_dir_path, "test")

assert os.path.isfile(pb_fname)
assert os.path.isfile(PATH_TO_LABELS)
TEST_IMAGE_PATHS = glob.glob(os.path.join(PATH_TO_TEST_IMAGES_DIR, "*.*"))
assert len(TEST_IMAGE_PATHS) > 0, 'No image found in `{}`.'.format(PATH_TO_TEST_IMAGES_DIR)
print(TEST_IMAGE_PATHS)
# Out:
# ['/content/object_detection_demo/data/images/test/BloodImage_00389.xml', '/content/object_detection_demo/data/images/test/BloodImage_00360.jpeg', '/content/object_detection_demo/data/images/test/BloodImage_00379.jpeg', '/content/object_detection_demo/data/images/test/BloodImage_00059.xml', '/content/object_detection_demo/data/images/test/BloodImage_00379.xml', '/content/object_detection_demo/data/images/test/BloodImage_00261.jpeg', '/content/object_detection_demo/data/images/test/BloodImage_00095.jpeg', '/content/object_detection_demo/data/images/test/BloodImage_00223.jpeg', '/content/object_detection_demo/data/images/test/BloodImage_00123.xml', '/content/object_detection_demo/data/images/test/BloodImage_00400.xml', '/content/object_detection_demo/data/images/test/BloodImage_00400.jpeg', '/content/object_detection_demo/data/images/test/BloodImage_00245.xml', '/content/object_detection_demo/data/images/test/BloodImage_00241.jpeg', '/content/object_detection_demo/data/images/test/BloodImage_00208.jpeg', '/content/object_detection_demo/data/images/test/BloodImage_00241.xml', '/content/object_detection_demo/data/images/test/BloodImage_00095.xml', '/content/object_detection_demo/data/images/test/BloodImage_00226.jpeg', '/content/object_detection_demo/data/images/test/BloodImage_00389.jpeg', '/content/object_detection_demo/data/images/test/BloodImage_00332.jpeg', '/content/object_detection_demo/data/images/test/BloodImage_00195.xml', '/content/object_detection_demo/data/images/test/BloodImage_00223.xml', '/content/object_detection_demo/data/images/test/BloodImage_00261.xml', '/content/object_detection_demo/data/images/test/BloodImage_00245.jpeg', '/content/object_detection_demo/data/images/test/BloodImage_00352.xml', '/content/object_detection_demo/data/images/test/BloodImage_00208.xml', '/content/object_detection_demo/data/images/test/BloodImage_00227.xml', '/content/object_detection_demo/data/images/test/BloodImage_00236.xml', '/content/object_detection_demo/data/images/test/BloodImage_00059.jpeg', '/content/object_detection_demo/data/images/test/BloodImage_00123.jpeg', '/content/object_detection_demo/data/images/test/BloodImage_00352.jpeg', '/content/object_detection_demo/data/images/test/BloodImage_00195.jpeg', '/content/object_detection_demo/data/images/test/BloodImage_00227.jpeg', '/content/object_detection_demo/data/images/test/BloodImage_00360.xml', '/content/object_detection_demo/data/images/test/BloodImage_00236.jpeg', '/content/object_detection_demo/data/images/test/BloodImage_00332.xml', '/content/object_detection_demo/data/images/test/BloodImage_00226.xml']

# %%
# %cd /content/models/research/object_detection

import numpy as np
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile

from collections import defaultdict
from io import StringIO
from matplotlib import pyplot as plt
from PIL import Image
from google.colab.patches import cv2_imshow

# This is needed since the notebook is stored in the object_detection folder.
sys.path.append("..")
from object_detection.utils import ops as utils_ops


# This is needed to display the images.
# %matplotlib inline


from object_detection.utils import label_map_util

from object_detection.utils import visualization_utils as vis_util


detection_graph = tf.Graph()
with detection_graph.as_default():
    od_graph_def = tf.GraphDef()
    with tf.gfile.GFile(PATH_TO_CKPT, 'rb') as fid:
        serialized_graph = fid.read()
        od_graph_def.ParseFromString(serialized_graph)
        tf.import_graph_def(od_graph_def, name='')


label_map = label_map_util.load_labelmap(PATH_TO_LABELS)
categories = label_map_util.convert_label_map_to_categories(
    label_map, max_num_classes=num_classes, use_display_name=True)
category_index = label_map_util.create_category_index(categories)


def load_image_into_numpy_array(image):
    (im_width, im_height) = image.size
    return np.array(image.getdata()).reshape(
        (im_height, im_width, 3)).astype(np.uint8)

# Size, in inches, of the output images.
IMAGE_SIZE = (12, 8)


def run_inference_for_single_image(image, graph):
    with graph.as_default():
        with tf.Session() as sess:
            # Get handles to input and output tensors
            ops = tf.get_default_graph().get_operations()
            all_tensor_names = {
                output.name for op in ops for output in op.outputs}
            tensor_dict = {}
            for key in [
                'num_detections', 'detection_boxes', 'detection_scores',
                'detection_classes', 'detection_masks'
            ]:
                tensor_name = key + ':0'
                if tensor_name in all_tensor_names:
                    tensor_dict[key] = tf.get_default_graph().get_tensor_by_name(
                        tensor_name)
            if 'detection_masks' in tensor_dict:
                # The following processing is only for single image
                detection_boxes = tf.squeeze(
                    tensor_dict['detection_boxes'], [0])
                detection_masks = tf.squeeze(
                    tensor_dict['detection_masks'], [0])
                # Reframe is required to translate mask from box coordinates to image coordinates and fit the image size.
                real_num_detection = tf.cast(
                    tensor_dict['num_detections'][0], tf.int32)
                detection_boxes = tf.slice(detection_boxes, [0, 0], [
                                           real_num_detection, -1])
                detection_masks = tf.slice(detection_masks, [0, 0, 0], [
                                           real_num_detection, -1, -1])
                detection_masks_reframed = utils_ops.reframe_box_masks_to_image_masks(
                    detection_masks, detection_boxes, image.shape[0], image.shape[1])
                detection_masks_reframed = tf.cast(
                    tf.greater(detection_masks_reframed, 0.5), tf.uint8)
                # Follow the convention by adding back the batch dimension
                tensor_dict['detection_masks'] = tf.expand_dims(
                    detection_masks_reframed, 0)
            image_tensor = tf.get_default_graph().get_tensor_by_name('image_tensor:0')

            # Run inference
            output_dict = sess.run(tensor_dict,
                                   feed_dict={image_tensor: np.expand_dims(image, 0)})

            # all outputs are float32 numpy arrays, so convert types as appropriate
            output_dict['num_detections'] = int(
                output_dict['num_detections'][0])
            output_dict['detection_classes'] = output_dict[
                'detection_classes'][0].astype(np.uint8)
            output_dict['detection_boxes'] = output_dict['detection_boxes'][0]
            output_dict['detection_scores'] = output_dict['detection_scores'][0]
            if 'detection_masks' in output_dict:
                output_dict['detection_masks'] = output_dict['detection_masks'][0]
    return output_dict


for image_path in TEST_IMAGE_PATHS:
    if '.jpeg' in image_path:
        image = Image.open(image_path)
        # the array based representation of the image will be used later in order to prepare the
        # result image with boxes and labels on it.
        image_np = load_image_into_numpy_array(image)
        # Expand dimensions since the model expects images to have shape: [1, None, None, 3]
        image_np_expanded = np.expand_dims(image_np, axis=0)
        # Actual detection.
        output_dict = run_inference_for_single_image(image_np, detection_graph)
        # Visualization of the results of a detection.
        vis_util.visualize_boxes_and_labels_on_image_array(
            image_np,
            output_dict['detection_boxes'],
            output_dict['detection_classes'],
            output_dict['detection_scores'],
            category_index,
            instance_masks=output_dict.get('detection_masks'),
            use_normalized_coordinates=True,
            line_thickness=8)
        plt.figure(figsize=IMAGE_SIZE)
        cv2_imshow(image_np)
        # plt.imshow(image_np)
        img_file_name = image_path.replace('/content/object_detection_demo/data/images/test/', '/content/gdrive/MyDrive/Projects/blood_cell/updated/results/rcnn/')
        # plt.savefig(img_file_name)
        im = Image.fromarray(image_np)
        im.save(img_file_name)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
